# %%
import requests

# %%
word = "ephemeral"

# %%
url = f"https://api.dictionaryapi.dev/api/v2/entries/en/{word}"

# %%
response = requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response)
# Out:
# <Response [200]>

# %%
type(response)
# Out:
# requests.models.Response

# %%
data=response.json()

# %%
type(data)
# Out:
# list

# %%
#entry = data[0]

# %%
print(data[0]['meanings'][1]['definitions'][0])
# Out:
# {'definition': 'Lasting for a short period of time.', 'synonyms': ['evanescent', 'fleeting', 'momentary', 'short', 'short-lived', 'temporary', 'transitory', 'volatile'], 'antonyms': ['eternal', 'everlasting', 'permanent', 'timeless']}
